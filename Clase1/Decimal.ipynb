# %% [markdown]
# **float**: punto flotante binario
#
# **decimal**: punto flotante decimal

# %% [markdown]
# La diferencia entre decimal y float, es que decimal si cumple con las reglas de aritmetica que vimos en la escuela!!!

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
n = 0.3

# %%
# sumo 10 veces n
n + n + n + n + n + n + n + n + n + n
# Out:
# 2.9999999999999996

# %%
n + n + n + n + n + n + n + n + n + n == 10 * n
# Out:
# False

# %%
n * 10
# Out:
# 3.0

# %%
import decimal

# %%
n = decimal.Decimal('0.3')
n
# Out:
# Decimal('0.3')

# %%
n + n + n + n + n + n + n + n + n + n == n * 10
# Out:
# True

# %%
n + n + n + n + n + n + n + n + n + n
# Out:
# Decimal('3.0')

# %%
n * 10
# Out:
# Decimal('3.0')

# %%
contexto = decimal.getcontext()
contexto
# Out:
# Context(prec=28, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[InvalidOperation, DivisionByZero, Overflow])

# %% [markdown]
# [Documentacion Decimal](https://docs.python.org/es/3/library/decimal.html)

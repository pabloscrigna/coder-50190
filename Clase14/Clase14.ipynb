# %% [markdown]
# <font size="6" color="rgb(128, 128, 0)">POO - Herencia</font>

# %% [markdown]
# * Herencia
# * Herencia Multiple
# * Polimorfismo
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Objetivos ✨

# %% [markdown]
# * **Aplicar** herencias.
# * **Conocer** los polimorfismos.
# * **Ejecutar** herencias múltiples.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Herencia

# %% [markdown]
# __¿Qué es?__
#
# La herencia es un proceso mediante el cual se puede crear una clase hija que hereda de una clase padre, compartiendo sus métodos y atributos.
#
# Además de ello, una clase hija puede sobreescribir los métodos o atributos, o incluso definir unos nuevos.

# %%
# Clase Padre

class Animal:
  pass

# %%
# Clase Hija que hereda de Padre

class Perro(Animal):
  pass

# %%
animal = Animal()
type(animal)

# %%
perro = Perro()
type(perro)

# %%
# Para saber de que clases hereda
Perro.__bases__

# %%
Animal.__bases__

# %% [markdown]
# __¿Como funciona?__
#
# Dado que una **clase hija hereda los atributos y métodos de la padre**, nos puede ser muy útil cuando tengamos clases que se parecen entre sí pero tienen ciertas particularidades.
#
# En este caso, siguiendo el ejemplo anterior, en vez de definir muchas clases para cada animal, **podemos tomar los elementos comunes y crear una clase Animal de la que hereden el resto**, respetando por tanto la filosofía **DRY**.
#
#
# **Las clases y la herencia ayudan a no repetir código de manera innecesaria.**

# %% [markdown]
# * calculadora_base.py
# * calculadora_cientifica.py
# * calculadora_herencia.py
# * calculadora_sobreescribir.py

# %% [markdown]
# **Preguntas**❓

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### **super**

# %% [markdown]
# **¿Para que sirve?**
#
#
# La función super  nos permite acceder a los métodos de la clase padre desde una de sus hijas.

# %% [markdown]
# * calculadora_super.py

# %% [markdown]
# **Preguntas**❓

# %% [markdown]
# ### ☕ Break

# %% [markdown]
# 10 minutos y volvemos!!!!!

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### **Herencia múltiple**

# %% [markdown]
# Hemos visto cómo se podía crear una clase padre que heredaba de una clase hija, pudiendo hacer uso de sus métodos y atributos.

# %% [markdown]
# **La herencia múltiple es similar, pero una clase hereda de varias clases padre en vez de una sola**.

# %%
class Clase1:
  pass

# %%
class Clase2(Clase1):
  pass

# %%
Clase2.__bases__

# %%
class Clase3(Clase2):
  pass

# %%
Clase3.__bases__

# %%
class ClaseA:
  pass

# %%
ClaseA.__bases__

# %%
class ClaseB:
  pass

# %%
ClaseB.__bases__

# %%
class ClaseC(ClaseA, ClaseB):
  pass

# %%
ClaseC.__bases__

# %% [markdown]
# * smartphone.py

# %% [markdown]
# **Preguntas**❓

# %% [markdown]
# **Method Order Resolution**

# %% [markdown]
# **Si llamo a un método que todas las clases tienen en común ¿A cuál se llama?**

# %% [markdown]
# Sabremos a qué método se llama, consultando al **MRO. Esta función nos devuelve una tupla con el orden de búsqueda de los métodos**.
#
# Como era de esperar se empieza en la propia clase y se va subiendo hasta la clase padre, de izquierda a derecha.

# %%
class Clase1:
  pass

# %%
class Clase2:
  pass

# %%
class Clase3:
  pass

# %%
class Clase4(Clase2, Clase1, Clase3):
  pass

# %%
Clase4.__mro__

# %%
Clase4.mro()

# %% [markdown]
# **En python...todo hereda de????**

# %%
int.__bases__

# %% [markdown]
# * smartphone_comun.py

# %% [markdown]
# **Preguntas**❓

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### **Polimorfismo**

# %% [markdown]
# **Ver guia Coder**

# %% [markdown]
# **Preguntas**❓

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### **Herencia y Encapsulamiento**

# %% [markdown]
# **Repaso encapsulamiento**
#
# * publico   ()
# * privado (_)
# * protegido   (__)

# %% [markdown]
# * permisos.py
# * herencia_encapsulamiento.py

# %% [markdown]
# **Preguntas**❓

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### **Ejercicio**

# %% [markdown]
# **Herencia múltiple**
#
# 1. Realiza la herencia múltiple respetando este diagrama de Clases UML. Y crear dos Cetáceos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ejercicio

# %% [markdown]
# **Extra**
#
# Metodo: __call__

# %%
class Exponenciacion:

  def __init__(self, exponente):
    self.exponente = exponente

  def __call__(self, base):
    return base ** self.exponente

# %%
operacion_expo = Exponenciacion(2)

# %%
operacion_expo(4)

# %%
operacion_expo(5)

# %% [markdown]
# **Decorador property**

# %% [markdown]
# **Preguntas**❓
